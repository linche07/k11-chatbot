# %%
import json
import os
import time
import random

# 数据存储路径
data_dir = '.'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# 存储数据到文件
def store_data(data, file_name):
    file_path = os.path.join(data_dir, file_name)
    with open(file_path, 'a') as f:
        json.dump(data, f)
        f.write('\n')
    print(f"Stored data: {data} into {file_name}")

# 模拟数据生成器
def generate_data():
    while True:
        # 模拟人流量数据
        foot_traffic = {
            "timestamp": time.strftime('%Y-%m-%d %H:%M:%S'),
            "entrances": random.randint(100, 500),
            "exits": random.randint(50, 300)
        }
        store_data(foot_traffic, 'foot_traffic.json')

        # 模拟环境监测数据
        env_data = {
            "timestamp": time.strftime('%Y-%m-%d %H:%M:%S'),
            "zone": "Main Hall",
            "temperature_c": round(random.uniform(22.0, 28.0), 2),
            "humidity_percent": round(random.uniform(50.0, 70.0), 2),
            "light_level_lux": random.randint(400, 700)
        }
        store_data(env_data, 'environment.json')

        # 模拟停车场数据
        parking_data = {
            "timestamp": time.strftime('%Y-%m-%d %H:%M:%S'),
            "parking_lot_id": "Lot_A",
            "available_spots": random.randint(0, 200),
            "total_spots": 200
        }
        store_data(parking_data, 'parking.json')

        # 模拟会员营销数据
        customer_data = {
            "customer_id": f"CUST_{random.randint(1, 1000)}",
            "purchase_amount": round(random.uniform(50, 2000), 2),
            "visit_frequency": random.randint(1, 20),
            "response_to_promotions": round(random.uniform(0, 1), 2)
        }
        store_data(customer_data, 'customer_data.json')

        # 模拟能源消耗数据
        energy_data = {
            "timestamp": time.strftime('%Y-%m-%d %H:%M:%S'),
            "hour": time.strftime('%H'),
            "day_of_week": time.strftime('%w'),
            "temperature": round(random.uniform(18, 35), 2),
            "humidity": round(random.uniform(30, 80), 2),
            "energy_consumption": round(random.uniform(200, 1000), 2)
        }
        store_data(energy_data, 'energy_consumption.json')

        # 模拟店舖绩效数据
        store_sales_data = {
            "store_id": f"STORE_{random.randint(1, 10)}",
            "date": time.strftime('%Y-%m-%d'),
            "foot_traffic": random.randint(100, 2000),
            "sales": round(random.uniform(500, 20000), 2),
            "promotion_spent": round(random.uniform(0, 5000), 2)
        }
        store_data(store_sales_data, 'store_sales.json')

        # 每2秒生成一次数据
        time.sleep(2)

# 启动数据生成器
generate_data()
# Out:
# Stored data: {'timestamp': '2024-08-14 21:58:23', 'entrances': 400, 'exits': 127} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:23', 'zone': 'Main Hall', 'temperature_c': 26.4, 'humidity_percent': 60.92, 'light_level_lux': 619} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:23', 'parking_lot_id': 'Lot_A', 'available_spots': 41, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_218', 'purchase_amount': 75.68, 'visit_frequency': 15, 'response_to_promotions': 0.47} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:23', 'hour': '21', 'day_of_week': '3', 'temperature': 25.67, 'humidity': 69.84, 'energy_consumption': 798.21} into energy_consumption.json
# Stored data: {'store_id': 'STORE_6', 'date': '2024-08-14', 'foot_traffic': 869, 'sales': 18374.05, 'promotion_spent': 2731.94} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:25', 'entrances': 385, 'exits': 61} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:25', 'zone': 'Main Hall', 'temperature_c': 26.63, 'humidity_percent': 52.33, 'light_level_lux': 648} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:25', 'parking_lot_id': 'Lot_A', 'available_spots': 194, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_39', 'purchase_amount': 968.36, 'visit_frequency': 11, 'response_to_promotions': 0.35} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:25', 'hour': '21', 'day_of_week': '3', 'temperature': 24.64, 'humidity': 54.17, 'energy_consumption': 462.55} into energy_consumption.json
# Stored data: {'store_id': 'STORE_4', 'date': '2024-08-14', 'foot_traffic': 612, 'sales': 2729.43, 'promotion_spent': 1669.25} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:27', 'entrances': 221, 'exits': 185} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:27', 'zone': 'Main Hall', 'temperature_c': 22.12, 'humidity_percent': 58.68, 'light_level_lux': 490} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:27', 'parking_lot_id': 'Lot_A', 'available_spots': 9, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_381', 'purchase_amount': 1886.63, 'visit_frequency': 11, 'response_to_promotions': 0.32} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:27', 'hour': '21', 'day_of_week': '3', 'temperature': 29.58, 'humidity': 46.37, 'energy_consumption': 982.59} into energy_consumption.json
# Stored data: {'store_id': 'STORE_8', 'date': '2024-08-14', 'foot_traffic': 1242, 'sales': 848.39, 'promotion_spent': 3263.57} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:29', 'entrances': 113, 'exits': 102} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:29', 'zone': 'Main Hall', 'temperature_c': 26.64, 'humidity_percent': 60.96, 'light_level_lux': 459} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:29', 'parking_lot_id': 'Lot_A', 'available_spots': 193, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_7', 'purchase_amount': 1989.57, 'visit_frequency': 17, 'response_to_promotions': 0.98} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:29', 'hour': '21', 'day_of_week': '3', 'temperature': 33.03, 'humidity': 44.63, 'energy_consumption': 556.21} into energy_consumption.json
# Stored data: {'store_id': 'STORE_4', 'date': '2024-08-14', 'foot_traffic': 155, 'sales': 7332.92, 'promotion_spent': 2870.47} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:31', 'entrances': 229, 'exits': 215} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:31', 'zone': 'Main Hall', 'temperature_c': 22.99, 'humidity_percent': 69.76, 'light_level_lux': 670} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:31', 'parking_lot_id': 'Lot_A', 'available_spots': 27, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_10', 'purchase_amount': 1581.73, 'visit_frequency': 13, 'response_to_promotions': 0.11} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:31', 'hour': '21', 'day_of_week': '3', 'temperature': 33.58, 'humidity': 55.53, 'energy_consumption': 358.95} into energy_consumption.json
# Stored data: {'store_id': 'STORE_7', 'date': '2024-08-14', 'foot_traffic': 955, 'sales': 8771.08, 'promotion_spent': 2567.87} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:33', 'entrances': 378, 'exits': 61} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:33', 'zone': 'Main Hall', 'temperature_c': 27.61, 'humidity_percent': 59.83, 'light_level_lux': 536} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:33', 'parking_lot_id': 'Lot_A', 'available_spots': 70, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_366', 'purchase_amount': 89.43, 'visit_frequency': 16, 'response_to_promotions': 0.11} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:33', 'hour': '21', 'day_of_week': '3', 'temperature': 20.69, 'humidity': 72.49, 'energy_consumption': 332.96} into energy_consumption.json
# Stored data: {'store_id': 'STORE_8', 'date': '2024-08-14', 'foot_traffic': 1070, 'sales': 18900.99, 'promotion_spent': 1613.25} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:35', 'entrances': 454, 'exits': 229} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:35', 'zone': 'Main Hall', 'temperature_c': 25.8, 'humidity_percent': 66.5, 'light_level_lux': 423} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:35', 'parking_lot_id': 'Lot_A', 'available_spots': 142, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_505', 'purchase_amount': 1320.57, 'visit_frequency': 20, 'response_to_promotions': 0.53} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:35', 'hour': '21', 'day_of_week': '3', 'temperature': 19.61, 'humidity': 34.31, 'energy_consumption': 915.11} into energy_consumption.json
# Stored data: {'store_id': 'STORE_8', 'date': '2024-08-14', 'foot_traffic': 1973, 'sales': 9627.09, 'promotion_spent': 4549.72} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:37', 'entrances': 265, 'exits': 148} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:37', 'zone': 'Main Hall', 'temperature_c': 27.47, 'humidity_percent': 52.61, 'light_level_lux': 602} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:37', 'parking_lot_id': 'Lot_A', 'available_spots': 125, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_670', 'purchase_amount': 1807.76, 'visit_frequency': 16, 'response_to_promotions': 0.45} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:37', 'hour': '21', 'day_of_week': '3', 'temperature': 23.75, 'humidity': 33.55, 'energy_consumption': 545.59} into energy_consumption.json
# Stored data: {'store_id': 'STORE_10', 'date': '2024-08-14', 'foot_traffic': 1878, 'sales': 15460.26, 'promotion_spent': 4791.88} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:39', 'entrances': 194, 'exits': 297} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:39', 'zone': 'Main Hall', 'temperature_c': 25.48, 'humidity_percent': 69.97, 'light_level_lux': 546} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:39', 'parking_lot_id': 'Lot_A', 'available_spots': 181, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_183', 'purchase_amount': 711.13, 'visit_frequency': 11, 'response_to_promotions': 0.41} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:39', 'hour': '21', 'day_of_week': '3', 'temperature': 29.57, 'humidity': 57.17, 'energy_consumption': 830.82} into energy_consumption.json
# Stored data: {'store_id': 'STORE_2', 'date': '2024-08-14', 'foot_traffic': 562, 'sales': 13035.4, 'promotion_spent': 190.64} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:41', 'entrances': 327, 'exits': 94} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:41', 'zone': 'Main Hall', 'temperature_c': 27.21, 'humidity_percent': 54.6, 'light_level_lux': 690} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:41', 'parking_lot_id': 'Lot_A', 'available_spots': 39, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_445', 'purchase_amount': 862.53, 'visit_frequency': 7, 'response_to_promotions': 0.9} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:41', 'hour': '21', 'day_of_week': '3', 'temperature': 33.19, 'humidity': 31.93, 'energy_consumption': 513.22} into energy_consumption.json
# Stored data: {'store_id': 'STORE_3', 'date': '2024-08-14', 'foot_traffic': 1471, 'sales': 18014.72, 'promotion_spent': 4419.86} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:43', 'entrances': 286, 'exits': 299} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:43', 'zone': 'Main Hall', 'temperature_c': 22.19, 'humidity_percent': 61.41, 'light_level_lux': 451} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:43', 'parking_lot_id': 'Lot_A', 'available_spots': 171, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_123', 'purchase_amount': 306.79, 'visit_frequency': 4, 'response_to_promotions': 0.24} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:43', 'hour': '21', 'day_of_week': '3', 'temperature': 30.37, 'humidity': 43.57, 'energy_consumption': 379.47} into energy_consumption.json
# Stored data: {'store_id': 'STORE_6', 'date': '2024-08-14', 'foot_traffic': 194, 'sales': 16644.84, 'promotion_spent': 386.61} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:45', 'entrances': 437, 'exits': 169} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:45', 'zone': 'Main Hall', 'temperature_c': 25.07, 'humidity_percent': 62.04, 'light_level_lux': 528} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:45', 'parking_lot_id': 'Lot_A', 'available_spots': 112, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_497', 'purchase_amount': 1041.87, 'visit_frequency': 8, 'response_to_promotions': 0.53} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:45', 'hour': '21', 'day_of_week': '3', 'temperature': 34.21, 'humidity': 43.4, 'energy_consumption': 454.75} into energy_consumption.json
# Stored data: {'store_id': 'STORE_7', 'date': '2024-08-14', 'foot_traffic': 1801, 'sales': 3133.77, 'promotion_spent': 914.44} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:47', 'entrances': 490, 'exits': 83} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:47', 'zone': 'Main Hall', 'temperature_c': 24.01, 'humidity_percent': 68.39, 'light_level_lux': 472} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:47', 'parking_lot_id': 'Lot_A', 'available_spots': 40, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_720', 'purchase_amount': 1102.47, 'visit_frequency': 4, 'response_to_promotions': 0.33} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:47', 'hour': '21', 'day_of_week': '3', 'temperature': 33.38, 'humidity': 32.21, 'energy_consumption': 996.08} into energy_consumption.json
# Stored data: {'store_id': 'STORE_6', 'date': '2024-08-14', 'foot_traffic': 1638, 'sales': 19577.42, 'promotion_spent': 4995.14} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:49', 'entrances': 323, 'exits': 297} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:49', 'zone': 'Main Hall', 'temperature_c': 24.74, 'humidity_percent': 61.4, 'light_level_lux': 497} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:49', 'parking_lot_id': 'Lot_A', 'available_spots': 172, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_483', 'purchase_amount': 916.57, 'visit_frequency': 6, 'response_to_promotions': 0.51} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:49', 'hour': '21', 'day_of_week': '3', 'temperature': 31.32, 'humidity': 43.89, 'energy_consumption': 365.41} into energy_consumption.json
# Stored data: {'store_id': 'STORE_7', 'date': '2024-08-14', 'foot_traffic': 537, 'sales': 2739.74, 'promotion_spent': 2399.39} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:51', 'entrances': 298, 'exits': 139} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:51', 'zone': 'Main Hall', 'temperature_c': 24.59, 'humidity_percent': 50.0, 'light_level_lux': 461} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:51', 'parking_lot_id': 'Lot_A', 'available_spots': 172, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_391', 'purchase_amount': 848.04, 'visit_frequency': 11, 'response_to_promotions': 0.01} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:51', 'hour': '21', 'day_of_week': '3', 'temperature': 23.34, 'humidity': 43.19, 'energy_consumption': 605.14} into energy_consumption.json
# Stored data: {'store_id': 'STORE_6', 'date': '2024-08-14', 'foot_traffic': 969, 'sales': 7560.42, 'promotion_spent': 1155.36} into store_sales.json
# Stored data: {'timestamp': '2024-08-14 21:58:53', 'entrances': 383, 'exits': 270} into foot_traffic.json
# Stored data: {'timestamp': '2024-08-14 21:58:53', 'zone': 'Main Hall', 'temperature_c': 27.82, 'humidity_percent': 67.62, 'light_level_lux': 641} into environment.json
# Stored data: {'timestamp': '2024-08-14 21:58:53', 'parking_lot_id': 'Lot_A', 'available_spots': 111, 'total_spots': 200} into parking.json
# Stored data: {'customer_id': 'CUST_745', 'purchase_amount': 328.13, 'visit_frequency': 19, 'response_to_promotions': 0.56} into customer_data.json
# Stored data: {'timestamp': '2024-08-14 21:58:53', 'hour': '21', 'day_of_week': '3', 'temperature': 32.92, 'humidity': 78.81, 'energy_consumption': 665.98} into energy_consumption.json
# Stored data: {'store_id': 'STORE_6', 'date': '2024-08-14', 'foot_traffic': 1581, 'sales': 4650.75, 'promotion_spent': 322.66} into store_sales.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 83
#      80         time.sleep(2)
#      82 # 启动数据生成器
# ---> 83 generate_data()
#
# Cell In[3], line 80, in generate_data()
#      77 store_data(store_sales_data, 'store_sales.json')
#      79 # 每2秒生成一次数据
# ---> 80 time.sleep(2)
#
# KeyboardInterrupt:
